# %%
# 1 :- WHAT IS def :- def means define a functaion 
#  YOU GIVE IT SOME INPUT 
# IT DOES SOME WORK 
# IT GIVES YOU OUTPUT

# 2 :- WHY WE USE def 
# WE WANT TO RESQUE CODE
# WE WANT TO CHECK LOGIC MANY TIMES 
# WE WANT CLEAN, ORGANIZED CODE

# 3 :- WHAT IS return :- return SENDS RESULT BACK


# 4 :- WHAT IS count():- count() HOW MANY TIMES A VALUE APPEARS
# a.count(19) IT MEANS HOW MANY TIMES 19 IN THE LIST a 

a =[19, 19, 15, 5, 3, 5, 5, 2]
def test(a):
    return a.count(19) == 2 and a.count(5) >= 3
print(test(a))
# Out:
# True

# %%
a = [19, 15, 15, 5, 3, 3, 5, 2]
def test(a):
    return a.count(19) == 2 and a.count(5) >= 3
print(test(a))
# Out:
# False

# %%
a = [19, 19, 5, 5, 5, 5, 5]
def test(a):
    return a.count(19) == 2 and a.count(5) >= 3
print(test(a))
# Out:
# True

# %%
a =[19, 19, 15, 5, 5, 5, 1, 2]
print(a[4])
# Out:
# 5

# %%
a =[19, 19, 15, 5, 5, 5, 1, 2]
if a.count(5) == 3:
    print("yes")
if len(a) == 8:
    print("true")
# Out:
# yes
# true

# %%
a =[19, 19, 15, 5, 5, 5, 1, 2]
def test(a):
    return len(a) == 8 and a.count(a[4]) == 3
print(test(a))
# Out:
# True

# %%
a = [19, 15, 5, 7, 5, 5, 2]
def test(a):
    return len(a) == 8 and a.count(a[4]) == 3
print(test(a))
# Out:
# False

# %%
a = [11, 12, 14, 13, 14, 13, 15, 14]
def test(a):
    return len(a) == 8 and a.count(a[4]) == 3
print(test(a))
# Out:
# True

# %%
a = [19, 15, 11, 7, 5, 6, 2]
def test(a):
    return len(a) == 8 and a.count(a[4]) == 3
print(test(a))
# Out:
# False

# %%
a = 922
def test(a):
    return 4**4 < 922 and a % 34 == 4
print(test(a))
# Out:
# True

# %%
a = 914
def test(a):
    return 4**4 < 914 and a % 34 == 4
print(test(a))
# Out:
# False

# %%
a = 854
def test(a):
    return a%34 == 4 and a > 4**4
print(test(a))
# Out:
# True
